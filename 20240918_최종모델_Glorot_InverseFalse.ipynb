# %% [markdown]
# <a href="https://colab.research.google.com/github/YeongLee-Smart/SUMAN/blob/main/20240918_%EC%B5%9C%EC%A2%85%EB%AA%A8%EB%8D%B8_Glorot_InverseFalse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Module

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from google.colab import drive
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from sklearn.metrics import recall_score, confusion_matrix, accuracy_score, classification_report, roc_curve, auc, roc_auc_score
from imblearn.over_sampling import SMOTE # For Oversampling
from sklearn.preprocessing import MinMaxScaler # Data Normalization (각 특징에 대해 0~1 사이 값으로 변환)
from sklearn.model_selection import StratifiedKFold #TrainData, TestData 분리(K-fold)

# %% [markdown]
# # Data Load

# %%
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Detect credit card anomalies/creditcard.csv'
data = pd.read_csv(file_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # EDA

# %%
# data.info() #결측치 없음
data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# # 원본 데이터 시각화

# %%
amount_original = data['Amount'].values
time_original = data['Time'].values

plt.subplots(constrained_layout=True)

plt.subplot(2, 1, 1)
plt.title('Transaction Amount Distribution')
plt.hist(amount_original, bins=50)

plt.subplot(2, 1, 2)
plt.title('Transaction Time Distribution')
plt.hist(time_original, bins=50)

plt.show()
# Out:
# <ipython-input-49-993f4f3db8c2>:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2, 1, 1)

# %% [markdown]
# # TrainData TestData 분리, Oversampling, Data Normalization

# %%
# 1. X, y 분리
X= data.iloc[:, :-1] # Time~Amount
Y= data.iloc[:, -1] # Class

# 2. Oversampling
smote = SMOTE(random_state=0)
X_resampled, Y_resampled = smote.fit_resample(X, Y)

# 3. 데이터 정규화 (각 특징에 대해 0~1 사이 값으로 변환)
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X_resampled) # X데이터를 scaling
X = pd.DataFrame(X_scaled, index=X_resampled.index, columns=X_resampled.columns) # X_scaled는 numpy이므로 DataFrame으로 변경

# 4. train, test 분리
kfold = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 0)

for train_index, test_index in kfold.split(X, Y_resampled):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = Y_resampled.iloc[train_index], Y_resampled.iloc[test_index]

print(X_train.shape, y_train.shape) #(227846, 30) (227846,) 80%
print(X_test.shape, y_test.shape) #(56961, 30) (56961,) 20%
# Out:
# (454904, 30) (454904,)
# (113726, 30) (113726,)

# %%
Y_resampled.value_counts() #Over Sampling check
# Out:
# Class
# 0    284315
# 1    284315
# Name: count, dtype: int64

# %% [markdown]
# # 정규화된 데이터 시각화

# %%
amount_normalized = X['Amount'].values
time_normalized = X['Time'].values

plt.subplots(constrained_layout=True)

plt.subplot(2, 1, 1)
plt.title('Transaction Amount Distribution')
plt.hist(amount_normalized, bins=50)

plt.subplot(2, 1, 2)
plt.title('Transaction Time Distribution')
plt.hist(time_normalized, bins=50)

plt.show()
# Out:
# <ipython-input-52-174f209d2bbb>:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2, 1, 1)

# %% [markdown]
# # Hyperparameter

# %% [markdown]
# ## learning_rate_decay 변경
#      exponential -> cosine -> inverse

# %% [markdown]
# ##EXP(Learning_Rate_Decay)

# %%
# 초기값 설정
initial_learning_rate = 0.01
decay_steps = 5
decay_rate = 0.95
epochs = np.arange(1, 101)

#Exponential Decay
exponential_decay = tf.keras.optimizers.schedules.ExponentialDecay(
     initial_learning_rate, decay_steps=decay_steps, decay_rate=decay_rate
 )


# 2. 배치크기
batch_size = 2**12 #13만 #train 데이터의 약 50%크기

# %% [markdown]
# ##Cosine Decay(Learning_Rate_Decay)

# %%
#Cosine Decay
CosineDecayValue=tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=0.01,
    decay_steps=100,
    alpha=0.001,
    # name='CosineDecay',
    warmup_target=None,
    warmup_steps=0
)

# 2. 배치크기
batch_size = 2**12 #13만 #train 데이터의 약 50%크기

# %% [markdown]
# ##Inverse(Learning_Rate_Decay)

# %%
#Inverse
InverseValue=tf.keras.optimizers.schedules.InverseTimeDecay(
    initial_learning_rate=0.01,
    decay_steps=20,
    decay_rate=0.95,
    staircase=False,
    name='InverseTimeDecay'
)

# 2. 배치크기
batch_size = 2**12 #13만 #train 데이터의 약 50%크기

# %% [markdown]
# ## Learning Rate Decay Visualization

# %%
# Learning_Rate 체크
learning_rate_check = []
for epoch in epochs:
    learning_rate = InverseValue(epoch)
    learning_rate_check.append(learning_rate.numpy())

# 학습율 시각화
plt.figure(figsize=(8, 6))
plt.plot(epochs, learning_rate_check, label='Learning Rate')
plt.xlabel('Epochs')
plt.ylabel('Learning Rate')
plt.title('Learning Rate over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Model 구축

# %% [markdown]
# ## Model 초기화

# %%
print(X_train.shape[1])
# Out:
# 30

# %%
model = Sequential()

#가중치 초기화(Weight Initailization)
# weight_init = tf.keras.initializers.he_uniform()
# weight_init = tf.keras.initializers.RandomNormal()
weight_init = tf.keras.initializers.glorot_uniform()

#model.add(Input(shape=(X_train.shape[1],)))
model.add(Dense(128, activation='relu', input_dim=30, kernel_initializer=weight_init))  # 첫 번째 은닉층
model.add(Dropout(0.5)) # 50% 드롭아웃 적용
model.add(Dense(64, activation='relu',kernel_initializer=weight_init))  # 두 번째 은닉층
model.add(Dropout(0.5))  # 50% 드롭아웃 적용
model.add(Dense(32, activation='relu',kernel_initializer=weight_init)) # 세 번째 은닉층
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_16 (Dense)                     │ (None, 128)                 │           3,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,337 (56.00 KB)
#  Trainable params: 14,337 (56.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Model Complie

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=InverseValue),
              loss = 'binary_crossentropy',
              metrics = ['accuracy'])

# %% [markdown]
# # Model Training

# %%
#생성된 데이터를 batch_size로 나누어, epoch만큼 학습시킴
history = model.fit(X_train, y_train, epochs=len(epochs), validation_data=(X_train, y_train), batch_size = batch_size)
# Out:
# Epoch 1/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - accuracy: 0.8739 - loss: 0.2693 - val_accuracy: 0.9703 - val_loss: 0.0837
# Epoch 2/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.9667 - loss: 0.0969 - val_accuracy: 0.9729 - val_loss: 0.0770
# Epoch 3/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.9690 - loss: 0.0899 - val_accuracy: 0.9740 - val_loss: 0.0731
# Epoch 4/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.9710 - loss: 0.0844 - val_accuracy: 0.9755 - val_loss: 0.0691
# Epoch 5/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9714 - loss: 0.0835 - val_accuracy: 0.9764 - val_loss: 0.0663
# Epoch 6/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.9729 - loss: 0.0795 - val_accuracy: 0.9769 - val_loss: 0.0656
# Epoch 7/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.9728 - loss: 0.0780 - val_accuracy: 0.9779 - val_loss: 0.0627
# Epoch 8/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - accuracy: 0.9732 - loss: 0.0764 - val_accuracy: 0.9783 - val_loss: 0.0619
# Epoch 9/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.9738 - loss: 0.0755 - val_accuracy: 0.9784 - val_loss: 0.0602
# Epoch 10/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.9746 - loss: 0.0733 - val_accuracy: 0.9789 - val_loss: 0.0590
# Epoch 11/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.9751 - loss: 0.0714 - val_accuracy: 0.9797 - val_loss: 0.0581
# Epoch 12/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.9758 - loss: 0.0697 - val_accuracy: 0.9795 - val_loss: 0.0574
# Epoch 13/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.9751 - loss: 0.0701 - val_accuracy: 0.9792 - val_loss: 0.0577
# Epoch 14/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.9760 - loss: 0.0689 - val_accuracy: 0.9804 - val_loss: 0.0558
# Epoch 15/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.9760 - loss: 0.0695 - val_accuracy: 0.9803 - val_loss: 0.0551
# Epoch 16/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9758 - loss: 0.0692 - val_accuracy: 0.9801 - val_loss: 0.0553
# Epoch 17/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.9764 - loss: 0.0674 - val_accuracy: 0.9808 - val_loss: 0.0538
# Epoch 18/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.9761 - loss: 0.0678 - val_accuracy: 0.9806 - val_loss: 0.0542
# Epoch 19/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9765 - loss: 0.0672 - val_accuracy: 0.9811 - val_loss: 0.0529
# Epoch 20/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.9769 - loss: 0.0660 - val_accuracy: 0.9813 - val_loss: 0.0524
# Epoch 21/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.
100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.9802 - loss: 0.0532 - val_accuracy: 0.9853 - val_loss: 0.0394
# Epoch 90/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.9804 - loss: 0.0538 - val_accuracy: 0.9854 - val_loss: 0.0394
# Epoch 91/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.9804 - loss: 0.0536 - val_accuracy: 0.9858 - val_loss: 0.0390
# Epoch 92/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - accuracy: 0.9799 - loss: 0.0535 - val_accuracy: 0.9852 - val_loss: 0.0397
# Epoch 93/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - accuracy: 0.9803 - loss: 0.0540 - val_accuracy: 0.9853 - val_loss: 0.0393
# Epoch 94/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.9805 - loss: 0.0528 - val_accuracy: 0.9852 - val_loss: 0.0391
# Epoch 95/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.9804 - loss: 0.0534 - val_accuracy: 0.9856 - val_loss: 0.0388
# Epoch 96/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.9805 - loss: 0.0531 - val_accuracy: 0.9855 - val_loss: 0.0390
# Epoch 97/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.9804 - loss: 0.0533 - val_accuracy: 0.9856 - val_loss: 0.0389
# Epoch 98/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.9809 - loss: 0.0527 - val_accuracy: 0.9854 - val_loss: 0.0389
# Epoch 99/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.9805 - loss: 0.0540 - val_accuracy: 0.9855 - val_loss: 0.0386
# Epoch 100/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.9802 - loss: 0.0526 - val_accuracy: 0.9854 - val_loss: 0.0387

# %% [markdown]
# ## Training Loss and Val_Loss Visualization

# %%
history_df = pd.DataFrame(history.history)
plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(history_df.loc[:, ['loss', 'val_loss']])
plt.subplot(122)
plt.plot(history_df.loc[:, ['accuracy', 'val_accuracy']])
# Out:
# [<matplotlib.lines.Line2D at 0x7f116e5f2bc0>,
#  <matplotlib.lines.Line2D at 0x7f116e5f2c20>]

# %%
plt.plot(history.history['loss'], label = "train")
plt.xlabel("Epochs")
plt.ylabel("Cost")
plt.title('Loss')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# # Model Evaluation

# %%
eval_loss, eval_acc = model.evaluate(X_test, y_test)
print(f"evaluation_acc = {eval_acc}")
print(f"evaluation_loss = {eval_loss}")
# Out:
# 3554/3554 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.9875 - loss: 0.0413
# evaluation_acc = 0.9848847389221191
# evaluation_loss = 0.04107615724205971

# %% [markdown]
# #Model Test

# %%
y_pred = model.predict(X_test)

print(y_pred[0])
print(y_test[0])
# Out:
# 3554/3554 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# [0.00058857]
# 0

# %%
plt.figure(figsize=(10,8))
plt.plot(y_pred) #그래프모양 변경가능
plt.grid()
plt.show()

# %%
y_pred_class = np.where(y_pred > 0.5, 1 , 0)
y_pred_class=pd.DataFrame(y_pred_class)
y_pred_class.value_counts()
# Out:
# 0    57344
# 1    56382
# Name: count, dtype: int64

# %% [markdown]
# #Recall

# %%
y_pred_class = np.where(y_pred > 0.5, 1 , 0) #0.5보다크면 1, 작으면 0
print(recall_score(y_test, y_pred_class))
# Out:
# 0.980655259131597

# %% [markdown]
# #Confusion Matrix

# %%
plt.figure(figsize=(6, 4))
cm = confusion_matrix(y_test, y_pred_class, labels=[0,1], normalize='true')
plt.title("Confusion Matrix")
sns.heatmap(cm,
            annot=True,
            fmt=".2%",
            cmap="Blues",
            xticklabels=["0","1"],
            yticklabels=["0","1"])

print(classification_report(y_test, y_pred_class)) #y_test = y_actual
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     56863
#            1       0.99      0.98      0.98     56863
#
#     accuracy                           0.98    113726
#    macro avg       0.98      0.98      0.98    113726
# weighted avg       0.98      0.98      0.98    113726

# %% [markdown]
# # ROC Curve

# %%
fpr, tpr, threshold = roc_curve(y_test, y_pred_class)

plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.grid(True)
plt.show()

# %% [markdown]
# # AUC

# %%
print(roc_auc_score(y_test, y_pred_class))
# Out:
# 0.9848847229305525
